# %%
pip install keras==2.15.0
# Out:
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.2 MB/s eta 0:00:00
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.3.3
#     Uninstalling keras-3.3.3:
#       Successfully uninstalled keras-3.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# Successfully installed keras-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2024-06-05 08:04:43.154570: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 08:04:43.154665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 08:04:43.269388: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.15.0
# 2.15.0

# %%
# Importing dependencies

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import *
import keras
from tensorflow.keras.callbacks import Callback

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score,RocCurveDisplay

SEED = 42
IMG_SIZE = 224, 224
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

# %%
# creating main dataframe contains image paths and their classes.

def create_images_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    for i in images:
        full_path.append(os.path.join(path, i))
    return full_path


classes = {0: 'Benign', 1: 'Malignant'}

train_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Benign')
train_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Malignant')

full_data = pd.concat([pd.DataFrame({'image' : train_benign_imgs, 'label': 0 }),
                      pd.DataFrame({'image' : train_malignant_imgs, 'label': 1 })])
# shuffling dataset
full_data = full_data.sample(frac = 1, ignore_index = True, random_state = SEED)

# train and valid splitting
train_data, valid_data = train_test_split(full_data, test_size = 0.2, stratify = full_data['label'])

train_data = train_data.reset_index(drop = True)
valid_data = valid_data.reset_index(drop = True)

# test dataframe
test_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Benign')
test_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Malignant')

test_data = pd.concat([pd.DataFrame({'image' : test_benign_imgs, 'label': 0 }),
                       pd.DataFrame({'image' : test_malignant_imgs, 'label': 1 })])
test_data = test_data.sample(frac = 1, ignore_index = True, random_state = SEED)


print('total train images \t{0}'.format(train_data.shape[0]))
print('total valid images \t{0}'.format(valid_data.shape[0]))
print('total test images \t{0}'.format(test_data.shape[0]))
# Out:
# total train images 	9503
# total valid images 	2376
# total test images 	2000

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Print 25 random samples from the training data with inferno colormap
plt.figure(figsize=(15, 15))

for i in range(25):
    ax = plt.subplot(5, 5, i+1)
    random_index = np.random.randint(0, train_data.shape[0])
    img_path = train_data.loc[random_index, 'image']
    img = Image.open(img_path)
    plt.imshow(img)
    ax.set_title(f"Label: {classes[train_data.loc[random_index, 'label']]}")
    ax.axis('off')

plt.show()

# %%
# Reading -> Resizing -> Normalization
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_png(img, channels = 3)
    img = tf.image.resize(img, size =(IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0


    return img, label


# Data augmentation
img_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation((-0.3, 0.3), interpolation="bilinear"),
    RandomContrast(0.03),
    RandomCrop(*IMG_SIZE)])

# %%
# Creating dataset loaders and tf.datasets

train_loader = tf.data.Dataset.from_tensor_slices((train_data['image'], train_data['label']))
train_dataset = (train_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .batch(BATCH_SIZE)
                 .map(lambda img, label: (img_augmentation(img), label), num_parallel_calls =AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_data['image'], valid_data['label']))
valid_dataset = (valid_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

test_loader = tf.data.Dataset.from_tensor_slices((test_data['image'], test_data['label']))
test_dataset = (test_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

# %%
# Display original and augmented image for the first sample
def display_sample_images(dataset):
    for images, labels in dataset.take(1):
        # Display original image
        original_image = images[0].numpy()
        
        # Apply augmentation
        augmented_image = img_augmentation(images[0:1], training=True)[0].numpy()
        
        # Plotting
        plt.figure(figsize=(8, 4))
        
        # Original image
        plt.subplot(1, 2, 1)
        plt.title("Original Image")
        plt.imshow(original_image,cmap='inferno')
        plt.axis("off")
        
        # Augmented image
        plt.subplot(1, 2, 2)
        plt.title("Augmented Image")
        plt.imshow(augmented_image,cmap='inferno')
        plt.axis("off")
        
        plt.show()
        break

# Display original and augmented images from train dataset
display_sample_images(train_dataset)

# %%
# a custom callback for evaluation of test set during training each 10 loop
class Test_Pred_During_Training(Callback):

    def __init__(self, model):
        self.model = model

    def on_epoch_end(self, epochs, logs = None ):
        try:
            if (epochs+1) % 10 == 0:
                test_pred = self.model.predict(test_dataset, verbose = 0)
                test_pred = np.argmax(test_pred, axis = 1)

                mse = mean_squared_error(test_data['label'], test_pred)
                f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
                acc = accuracy_score(test_data['label'], test_pred)

                print('\nMean Squared Error : {0:.5f}'.format(mse))
                print('Weighted F1 Score : {0:.3f}'.format(f1))
                print('Accuracy Score : {0:.3f} %'.format(acc*100))

                print("--"*40)
        except ValueError:
            pass

# %%
# !pip install tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow-hub in /opt/conda/lib/python3.10/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow-hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow-hub) (2.15.1)
# Requirement already satisfied: tensorflow<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (21.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.2.2)
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'

# %%
import tensorflow_hub as hub
bit_model_url = "https://www.kaggle.com/models/google/bit/TensorFlow2/m-r152x4/1"
bit_module = hub.KerasLayer(bit_model_url)
# Out:
# Attaching model 'google/bit/tensorflow2/m-r152x4/1' to your Kaggle notebook...

# %%
from tensorflow import keras
class MyBiTModel(keras.Model):
    def __init__(self, num_classes, module, **kwargs):
        super().__init__(**kwargs)

        self.num_classes = num_classes
        self.head = keras.layers.Dense(num_classes, kernel_initializer="zeros", activation='softmax')
        self.bit_model = module

    def call(self, images):
        bit_embedding = self.bit_model(images)
        return self.head(bit_embedding)


model = MyBiTModel(num_classes=2, module=bit_module)

# %%
SCHEDULE_BOUNDARIES = [
    10,
    30
] 
learning_rate = 0.001 * BATCH_SIZE / 512

# Decay learning rate by a factor of 10 at SCHEDULE_BOUNDARIES.
lr_schedule = keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries=SCHEDULE_BOUNDARIES,
    values=[
        learning_rate,
        learning_rate * 0.1,
        learning_rate * 0.01,
    ],
)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
# model.summary()

# %%
my_callbacks = [Test_Pred_During_Training(model),
                tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor=0.1, min_delta = 0.01, patience=6),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0.01,patience=20),
                tf.keras.callbacks.ModelCheckpoint("/kaggle/working/my_model.tf", monitor="val_loss", mode="min", save_best_only=True, verbose=1)]

# %%
import time
start = time.time()
history = model.fit(
    train_dataset,
    batch_size=32,
    epochs=50,
    validation_data=valid_dataset,
    callbacks=[my_callbacks]
)
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
#   1/297 [..............................] - ETA: 4:22:12 - loss: 0.6931 - accuracy: 0.6250
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717574854.164081      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 297/297 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.8387
# Epoch 1: val_loss improved from inf to 0.42318, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 838s 3s/step - loss: 0.4276 - accuracy: 0.8387 - val_loss: 0.4232 - val_accuracy: 0.8514 - lr: 6.2500e-07
# Epoch 2/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8512
# Epoch 2: val_loss improved from 0.42318 to 0.40328, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.3987 - accuracy: 0.8512 - val_loss: 0.4033 - val_accuracy: 0.8577 - lr: 6.2500e-07
# Epoch 3/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8571
# Epoch 3: val_loss improved from 0.40328 to 0.38727, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 778s 3s/step - loss: 0.3793 - accuracy: 0.8571 - val_loss: 0.3873 - val_accuracy: 0.8607 - lr: 6.2500e-07
# Epoch 4/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8600
# Epoch 4: val_loss improved from 0.38727 to 0.37443, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.3649 - accuracy: 0.8600 - val_loss: 0.3744 - val_accuracy: 0.8620 - lr: 6.2500e-07
# Epoch 5/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.8638
# Epoch 5: val_loss improved from 0.37443 to 0.36358, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.3535 - accuracy: 0.8638 - val_loss: 0.3636 - val_accuracy: 0.8615 - lr: 6.2500e-07
# Epoch 6/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8630
# Epoch 6: val_loss improved from 0.36358 to 0.35472, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 779s 3s/step - loss: 0.3443 - accuracy: 0.8630 - val_loss: 0.3547 - val_accuracy: 0.8611 - lr: 6.2500e-07
# Epoch 7/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8674
# Epoch 7: val_loss improved from 0.35472 to 0.34709, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.3357 - accuracy: 0.8674 - val_loss: 0.3471 - val_accuracy: 0.8632 - lr: 6.2500e-07
# Epoch 8/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8717
# Epoch 8: val_loss improved from 0.34709 to 0.34072, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.3281 - accuracy: 0.8717 - val_loss: 0.3407 - val_accuracy: 0.8649 - lr: 6.2500e-07
# Epoch 9/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.8738
# Epoch 9: val_loss improved from 0.34072 to 0.33521, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.3218 - accuracy: 0.8738 - val_loss: 0.3352 - val_accuracy: 0.8670 - lr: 6.2500e-07
# Epoch 10/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8723
# Mean Squared Error : 0.12850
# Weighted F1 Score : 0.871
# Accuracy Score : 87.150 %
# --------------------------------------------------------------------------------
#
# Epoch 10: val_loss improved from 0.33521 to 0.33032, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 911s 3s/step - loss: 0.3176 - accuracy: 0.8723 - val_loss: 0.3303 - val_accuracy: 0.8687 - lr: 6.2500e-07
# Epoch 11/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.8728
# Epoch 11: val_loss improved from 0.33032 to 0.32536, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 779s 3s/step - loss: 0.3142 - accuracy: 0.8728 - val_loss: 0.3254 - val_accuracy: 0.8712 - lr: 6.2500e-07
# Epoch 12/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8751
# Epoch 12: val_loss improved from 0.32536 to 0.32111, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 768s 3s/step - loss: 0.3093 - accuracy: 0.8751 - val_loss: 0.3211 - val_accuracy: 0.8721 - lr: 6.2500e-07
# Epoch 13/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3051 - accuracy: 0.8760
# Epoch 13: val_loss improved from 0.32111 to 0.31794, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 779s 3s/step - loss: 0.3051 - accuracy: 0.8760 - val_loss: 0.3179 - val_accuracy: 0.8733 - lr: 6.2500e-07
# Epoch 14/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.8765
# Epoch 14: val_loss improved from 0.31794 to 0.31482, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 782s 3s/step - loss: 0.3007 - accuracy: 0.8765 - val_loss: 0.3148 - val_accuracy: 0.8737 - lr: 6.2500e-07
# Epoch 15/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8778
# Epoch 15: val_loss improved from 0.31482 to 0.31171, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.2984 - accuracy: 0.8778 - val_loss: 0.3117 - val_accuracy: 0.8737 - lr: 6.2500e-07
# Epoch 16/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.8781
# Epoch 16: val_loss improved from 0.31171 to 0.30923, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.2971 - accuracy: 0.8781 - val_loss: 0.3092 - val_accuracy: 0.8737 - lr: 6.2500e-07
# Epoch 17/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2942 - accuracy: 0.8785
# Epoch 17: val_loss improved from 0.30923 to 0.30677, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.2942 - accuracy: 0.8785 - val_loss: 0.3068 - val_accuracy: 0.8733 - lr: 6.2500e-07
# Epoch 18/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8784
# Epoch 18: val_loss improved from 0.30677 to 0.30483, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.2896 - accuracy: 0.8784 - val_loss: 0.3048 - val_accuracy: 0.8742 - lr: 6.2500e-07
# Epoch 19/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.8797
# Epoch 19: val_loss improved from 0.30483 to 0.30307, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 781s 3s/step - loss: 0.2882 - accuracy: 0.8797 - val_loss: 0.3031 - val_accuracy: 0.8750 - lr: 6.2500e-07
# Epoch 20/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.8821
# Mean Squared Error : 0.11700
# Weighted F1 Score : 0.883
# Accuracy Score : 88.300 %
# --------------------------------------------------------------------------------
#
# Epoch 20: val_loss improved from 0.30307 to 0.30151, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 903s 3s/step - loss: 0.2870 - accuracy: 0.8821 - val_loss: 0.3015 - val_accuracy: 0.8758 - lr: 6.2500e-07
# Epoch 21/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.8804
# Epoch 21: val_loss improved from 0.30151 to 0.29977, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 782s 3s/step - loss: 0.2853 - accuracy: 0.8804 - val_loss: 0.2998 - val_accuracy: 0.8758 - lr: 6.2500e-07
# Epoch 22/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8807
# Epoch 22: val_loss improved from 0.29977 to 0.29852, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 785s 3s/step - loss: 0.2847 - accuracy: 0.8807 - val_loss: 0.2985 - val_accuracy: 0.8763 - lr: 6.2500e-07
# Epoch 23/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.8819
# Epoch 23: val_loss improved from 0.29852 to 0.29686, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 786s 3s/step - loss: 0.2816 - accuracy: 0.8819 - val_loss: 0.2969 - val_accuracy: 0.8767 - lr: 6.2500e-07
# Epoch 24/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8799
# Epoch 24: val_loss improved from 0.29686 to 0.29539, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 784s 3s/step - loss: 0.2817 - accuracy: 0.8799 - val_loss: 0.2954 - val_accuracy: 0.8754 - lr: 6.2500e-07
# Epoch 25/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8838
# Epoch 25: val_loss improved from 0.29539 to 0.29410, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 785s 3s/step - loss: 0.2795 - accuracy: 0.8838 - val_loss: 0.2941 - val_accuracy: 0.8758 - lr: 6.2500e-07
# Epoch 26/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8826
# Epoch 26: val_loss improved from 0.29410 to 0.29296, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 787s 3s/step - loss: 0.2782 - accuracy: 0.8826 - val_loss: 0.2930 - val_accuracy: 0.8763 - lr: 6.2500e-07
# Epoch 27/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.8827
# Epoch 27: val_loss improved from 0.29296 to 0.29168, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 779s 3s/step - loss: 0.2778 - accuracy: 0.8827 - val_loss: 0.2917 - val_accuracy: 0.8763 - lr: 6.2500e-07
# Epoch 28/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.8845
# Epoch 28: val_loss improved from 0.29168 to 0.29029, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 788s 3s/step - loss: 0.2762 - accuracy: 0.8845 - val_loss: 0.2903 - val_accuracy: 0.8771 - lr: 6.2500e-07
# Epoch 29/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.8850
# Epoch 29: val_loss improved from 0.29029 to 0.28970, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 782s 3s/step - loss: 0.2747 - accuracy: 0.8850 - val_loss: 0.2897 - val_accuracy: 0.8771 - lr: 6.2500e-07
# Epoch 30/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.8845
# Mean Squared Error : 0.11200
# Weighted F1 Score : 0.888
# Accuracy Score : 88.800 %
# --------------------------------------------------------------------------------
#
# Epoch 30: val_loss improved from 0.28970 to 0.28866, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 908s 3s/step - loss: 0.2737 - accuracy: 0.8845 - val_loss: 0.2887 - val_accuracy: 0.8771 - lr: 6.2500e-07
# Epoch 31/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.8815
# Epoch 31: val_loss improved from 0.28866 to 0.28722, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 786s 3s/step - loss: 0.2727 - accuracy: 0.8815 - val_loss: 0.2872 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 32/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8851
# Epoch 32: val_loss improved from 0.28722 to 0.28691, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 786s 3s/step - loss: 0.2716 - accuracy: 0.8851 - val_loss: 0.2869 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 33/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8891
# Epoch 33: val_loss improved from 0.28691 to 0.28599, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 785s 3s/step - loss: 0.2715 - accuracy: 0.8891 - val_loss: 0.2860 - val_accuracy: 0.8788 - lr: 6.2500e-07
# Epoch 34/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8844
# Epoch 34: val_loss improved from 0.28599 to 0.28509, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 785s 3s/step - loss: 0.2715 - accuracy: 0.8844 - val_loss: 0.2851 - val_accuracy: 0.8788 - lr: 6.2500e-07
# Epoch 35/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.8856
# Epoch 35: val_loss improved from 0.28509 to 0.28451, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 843s 3s/step - loss: 0.2705 - accuracy: 0.8856 - val_loss: 0.2845 - val_accuracy: 0.8788 - lr: 6.2500e-07
# Epoch 36/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2697 - accuracy: 0.8870
# Epoch 36: val_loss improved from 0.28451 to 0.28449, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 788s 3s/step - loss: 0.2697 - accuracy: 0.8870 - val_loss: 0.2845 - val_accuracy: 0.8775 - lr: 6.2500e-07
# Epoch 37/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.8880
# Epoch 37: val_loss improved from 0.28449 to 0.28358, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 790s 3s/step - loss: 0.2661 - accuracy: 0.8880 - val_loss: 0.2836 - val_accuracy: 0.8788 - lr: 6.2500e-07
# Epoch 38/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8857
# Epoch 38: val_loss improved from 0.28358 to 0.28268, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 791s 3s/step - loss: 0.2683 - accuracy: 0.8857 - val_loss: 0.2827 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 39/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8877
# Epoch 39: val_loss improved from 0.28268 to 0.28200, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 788s 3s/step - loss: 0.2670 - accuracy: 0.8877 - val_loss: 0.2820 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 40/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.8879
# Mean Squared Error : 0.10900
# Weighted F1 Score : 0.891
# Accuracy Score : 89.100 %
# --------------------------------------------------------------------------------
#
# Epoch 40: val_loss improved from 0.28200 to 0.28143, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 911s 3s/step - loss: 0.2661 - accuracy: 0.8879 - val_loss: 0.2814 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 41/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.8869
# Epoch 41: val_loss improved from 0.28143 to 0.28076, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 782s 3s/step - loss: 0.2642 - accuracy: 0.8869 - val_loss: 0.2808 - val_accuracy: 0.8779 - lr: 6.2500e-07
# Epoch 42/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8878
# Epoch 42: val_loss improved from 0.28076 to 0.28023, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 783s 3s/step - loss: 0.2647 - accuracy: 0.8878 - val_loss: 0.2802 - val_accuracy: 0.8788 - lr: 6.2500e-07
# Epoch 43/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.8876
# Epoch 43: val_loss improved from 0.28023 to 0.27963, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 783s 3s/step - loss: 0.2643 - accuracy: 0.8876 - val_loss: 0.2796 - val_accuracy: 0.8792 - lr: 6.2500e-07
# Epoch 44/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8879
# Epoch 44: val_loss improved from 0.27963 to 0.27896, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 785s 3s/step - loss: 0.2647 - accuracy: 0.8879 - val_loss: 0.2790 - val_accuracy: 0.8796 - lr: 6.2500e-07
# Epoch 45/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.8872
# Epoch 45: val_loss improved from 0.27896 to 0.27848, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 780s 3s/step - loss: 0.2625 - accuracy: 0.8872 - val_loss: 0.2785 - val_accuracy: 0.8801 - lr: 6.2500e-07
# Epoch 46/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.8880
# Epoch 46: val_loss improved from 0.27848 to 0.27779, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 787s 3s/step - loss: 0.2613 - accuracy: 0.8880 - val_loss: 0.2778 - val_accuracy: 0.8813 - lr: 6.2500e-07
# Epoch 47/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8879
# Epoch 47: val_loss improved from 0.27779 to 0.27710, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 784s 3s/step - loss: 0.2630 - accuracy: 0.8879 - val_loss: 0.2771 - val_accuracy: 0.8817 - lr: 6.2500e-07
# Epoch 48/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.8878
# Epoch 48: val_loss did not improve from 0.27710
# 297/297 [==============================] - 723s 2s/step - loss: 0.2616 - accuracy: 0.8878 - val_loss: 0.2772 - val_accuracy: 0.8813 - lr: 6.2500e-07
# Epoch 49/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8910
# Epoch 49: val_loss improved from 0.27710 to 0.27678, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 784s 3s/step - loss: 0.2603 - accuracy: 0.8910 - val_loss: 0.2768 - val_accuracy: 0.8813 - lr: 6.2500e-07
# Epoch 50/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8911
# Mean Squared Error : 0.10750
# Weighted F1 Score : 0.892
# Accuracy Score : 89.250 %
# --------------------------------------------------------------------------------
#
# Epoch 50: val_loss improved from 0.27678 to 0.27627, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 907s 3s/step - loss: 0.2601 - accuracy: 0.8911 - val_loss: 0.2763 - val_accuracy: 0.8813 - lr: 6.2500e-07
# Total time:  39959.08358860016 seconds

# %%
# Print training results
print("Training Results:")
print("Loss:", history.history['loss'][-1])
print("Accuracy:", history.history['accuracy'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Training Results:
# Loss: 0.26010316610336304
# Accuracy: 0.891086995601654
# Validation Loss: 0.2762725055217743
# Validation Accuracy: 0.881313145160675

# %%
fig, axs = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

axs.grid(linestyle='dashdot')
axs.plot(history.history['loss'])
axs.plot(history.history['val_loss'])
axs.set_xlabel('epochs', fontsize=10)
axs.set_ylabel('Loss', fontsize=10)
axs.legend(['Train Loss', 'Validation Loss'], fontsize=10)
axs.set_ylim(0, 1)
print(f'Loss: Train Loss = {history.history["loss"][-1]:.4f}, Validation Loss = {history.history["val_loss"][-1]:.4f}')
# Out:
# Loss: Train Loss = 0.2601, Validation Loss = 0.2763

# %%
fig, axs = plt.subplots(1,1, figsize = (5, 5), dpi = 100)
axs.grid(linestyle = 'dashdot')
axs.plot(history.history['accuracy'])
axs.plot(history.history['val_accuracy'])
axs.set_xlabel('epochs', fontsize = 10)
axs.legend(['train accuracy', 'validation accuracy'], fontsize = 10)
axs.set_ylim(0, 1)
print(f'Accuract: Train Accuracy = {history.history["accuracy"][-1]:.4f}, Validation Accuracy = {history.history["val_accuracy"][-1]:.4f}')
# Out:
# Accuract: Train Accuracy = 0.8911, Validation Accuracy = 0.8813

# %%
# Predictions and scores
test_pred = model.predict(test_dataset)
test_pred = np.argmax(test_pred, axis = 1)

mse = mean_squared_error(test_data['label'], test_pred)
f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
acc = accuracy_score(test_data['label'], test_pred)

print('Mean Squared Error : {0:.5f}'.format(mse))
print('Weighted F1 Score : {0:.3f}'.format(f1))
print('Accuracy Score : {0:.3f} %'.format(acc*100))
# Out:
# 63/63 [==============================] - 121s 2s/step
# Mean Squared Error : 0.10750
# Weighted F1 Score : 0.892
# Accuracy Score : 89.250 %

# %%
clf = classification_report(test_data['label'], test_pred, target_names = list(classes.values()))
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.88      0.91      0.89      1000
#    Malignant       0.91      0.88      0.89      1000
#
#     accuracy                           0.89      2000
#    macro avg       0.89      0.89      0.89      2000
# weighted avg       0.89      0.89      0.89      2000

# %%
cm = confusion_matrix(test_data['label'], test_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels = list(classes.values()))

fig, ax = plt.subplots(figsize=(5,5))
cmd.plot(ax=ax,  cmap = 'Blues', colorbar = False)

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_dataset)

# Print test results
print("\nTest Results:")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 63/63 [==============================] - 122s 2s/step - loss: 0.2780 - accuracy: 0.8925
#
# Test Results:
# Test Loss: 0.27803686261177063
# Test Accuracy: 0.8924999833106995

# %%
import matplotlib.pyplot as plt

# Create a bar chart
x = ['Test Loss', 'Test Accuracy']
y = [test_loss, test_acc]

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(x, y)

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Model Evaluation on Test Set')

# Add value labels to the bars
for i, v in enumerate(y):
    ax.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=10)

plt.show()

# %%
# y_true = test_data['label']
# y_pred = model.predict(test_dataset, verbose=0)[:, 1]

# fpr, tpr, thresholds = roc_curve(y_true, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.figure(figsize=(8, 6))
# plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic (ROC)')
# plt.legend(loc="lower right")
# plt.show()

# %%
test_take1 =  test_dataset.take(-1)
test_take1_ = list(test_take1)

# A function that creating 5 random images in the test set and predictions

# Red title -> a false prediction
# Green title -> a true prediction

def random_test_sample_with_prediction(SEED):
    idxs = np.random.default_rng(seed=SEED).permutation(len(test_pred))[:5]
    batch_idx = idxs // BATCH_SIZE
    image_idx = idxs - batch_idx * BATCH_SIZE
    idx = idxs

    fig, axs = plt.subplots(1, 5, figsize=(12, 12), dpi=150)

    for i in range(5):
        img = test_take1_[batch_idx[i]][0][image_idx[i]]
        label = test_take1_[batch_idx[i]][1][image_idx[i]].numpy()
        pred = model.predict(tf.expand_dims(img, axis=0))[0]
        pred_label = np.argmax(pred)  # Lấy nhãn dự đoán có xác suất cao nhất
        pred_prob = pred[pred_label]  # Xác suất của nhãn dự đoán

        if pred_label == label:
            axs[i].imshow(img, cmap='gray')
            axs[i].axis('off')
            axs[i].set_title(f'image (no: {idx[i]})\nTRUE: {classes[label]}\nPRED: {classes[pred_label]} ({pred_prob:.2%})', fontsize=8, color='green')
        else:
            axs[i].imshow(img, cmap='gray')
            axs[i].axis('off')
            axs[i].set_title(f'image (no: {idx[i]})\nTRUE: {classes[label]}\nPRED: {classes[pred_label]} ({pred_prob:.2%})', fontsize=8, color='red')

# %%
# Red title -> a false prediction
# Green title -> a true prediction

random_test_sample_with_prediction(21)
random_test_sample_with_prediction(204)
random_test_sample_with_prediction(293)
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 183ms/step

# %%
loaded_model = tf.keras.models.load_model('/kaggle/working/my_model.tf')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# 5742
test_image_path = '/kaggle/input/melanoma-cancer-dataset/test/Malignant/5742.jpg'

test_image = cv2.imread(test_image_path)
test_image = cv2.resize(test_image, (224, 224))
test_image_display = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
test_image_normalized = test_image / 255.0
test_image_normalized = np.expand_dims(test_image_normalized, axis=0)

predictions = loaded_model.predict(test_image_normalized)
predicted_class_index = np.argmax(predictions)
if predicted_class_index == 0:
    predicted_class = 'Benign'
else:
    predicted_class = 'Malignant'

predicted_accuracy = np.max(predictions) *100

# if predicted_class_index == 1:
#     bounding_box = [50, 70, 150, 120]
#     cv2.rectangle(test_image_display, (bounding_box[0], bounding_box[1]), (bounding_box[2], bounding_box[3]), (0, 255, 0), 2)

plt.imshow(test_image_display)
plt.title(f"{predicted_class} ({predicted_accuracy:.2f}% accuracy)")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 6s 6s/step
