# %%
pip install keras==2.15.0
# Out:
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.7 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# Successfully installed keras-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2024-06-04 15:53:14.465787: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 15:53:14.465912: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 15:53:14.577101: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.15.0
# 2.15.0

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import *
import keras
from tensorflow.keras.callbacks import Callback

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score,RocCurveDisplay

SEED = 42
IMG_SIZE = 224, 224
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

# %% [markdown]
# # <span style="color:#e74c3c;"> Reading </span> Data

# %%
# creating main dataframe contains image paths and their classes.

def create_images_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    for i in images:
        full_path.append(os.path.join(path, i))
    return full_path


classes = {0: 'Benign', 1: 'Malignant'}

train_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Benign')
train_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Malignant')

full_data = pd.concat([pd.DataFrame({'image' : train_benign_imgs, 'label': 0 }),
                      pd.DataFrame({'image' : train_malignant_imgs, 'label': 1 })])
# shuffling dataset
full_data = full_data.sample(frac = 1, ignore_index = True, random_state = SEED)

# train and valid splitting
train_data, valid_data = train_test_split(full_data, test_size = 0.2, stratify = full_data['label'])

train_data = train_data.reset_index(drop = True)
valid_data = valid_data.reset_index(drop = True)

# test dataframe
test_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Benign')
test_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Malignant')

test_data = pd.concat([pd.DataFrame({'image' : test_benign_imgs, 'label': 0 }),
                       pd.DataFrame({'image' : test_malignant_imgs, 'label': 1 })])
test_data = test_data.sample(frac = 1, ignore_index = True, random_state = SEED)


print('total train images \t{0}'.format(train_data.shape[0]))
print('total valid images \t{0}'.format(valid_data.shape[0]))
print('total test images \t{0}'.format(test_data.shape[0]))
# Out:
# total train images 	9503
# total valid images 	2376
# total test images 	2000

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Print 25 random samples from the training data with inferno colormap
plt.figure(figsize=(15, 15))

for i in range(25):
    ax = plt.subplot(5, 5, i+1)
    random_index = np.random.randint(0, train_data.shape[0])
    img_path = train_data.loc[random_index, 'image']
    img = Image.open(img_path)
    plt.imshow(img)
    ax.set_title(f"Label: {classes[train_data.loc[random_index, 'label']]}")
    ax.axis('off')

plt.show()

# %%
# Reading -> Resizing -> Normalization
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_png(img, channels = 3)
    img = tf.image.resize(img, size =(IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0


    return img, label


# Data augmentation
img_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation((-0.3, 0.3), interpolation="bilinear"),
    RandomContrast(0.03),
    RandomCrop(*IMG_SIZE)])

# %%
# Creating dataset loaders and tf.datasets

train_loader = tf.data.Dataset.from_tensor_slices((train_data['image'], train_data['label']))
train_dataset = (train_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .batch(BATCH_SIZE)
                 .map(lambda img, label: (img_augmentation(img), label), num_parallel_calls =AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_data['image'], valid_data['label']))
valid_dataset = (valid_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

test_loader = tf.data.Dataset.from_tensor_slices((test_data['image'], test_data['label']))
test_dataset = (test_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

# %%
# Display original and augmented image for the first sample
def display_sample_images(dataset):
    for images, labels in dataset.take(1):
        # Display original image
        original_image = images[0].numpy()
        
        # Apply augmentation
        augmented_image = img_augmentation(images[0:1], training=True)[0].numpy()
        
        # Plotting
        plt.figure(figsize=(8, 4))
        
        # Original image
        plt.subplot(1, 2, 1)
        plt.title("Original Image")
        plt.imshow(original_image,cmap='inferno')
        plt.axis("off")
        
        # Augmented image
        plt.subplot(1, 2, 2)
        plt.title("Augmented Image")
        plt.imshow(augmented_image,cmap='inferno')
        plt.axis("off")
        
        plt.show()
        break

# Display original and augmented images from train dataset
display_sample_images(train_dataset)

# %%
# a custom callback for evaluation of test set during training each 10 loop
class Test_Pred_During_Training(Callback):

    def __init__(self, model):
        self._model = model

    def on_epoch_end(self, epochs, logs = None ):
        try:
            if (epochs+1) % 10 == 0:
                test_pred = self.model.predict(test_dataset, verbose = 0)
                test_pred = np.argmax(test_pred, axis = 1)

                mse = mean_squared_error(test_data['label'], test_pred)
                f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
                acc = accuracy_score(test_data['label'], test_pred)

                print('\nMean Squared Error : {0:.5f}'.format(mse))
                print('Weighted F1 Score : {0:.3f}'.format(f1))
                print('Accuracy Score : {0:.3f} %'.format(acc*100))

                print("--"*40)
        except ValueError:
            pass

# %%
pip install -q vit-keras
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.1.1)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 11.8 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.1.5
#     Uninstalling typeguard-4.1.5:
#       Successfully uninstalled typeguard-4.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires typeguard<5,>=4.1.2, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from vit_keras import vit
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications.convnext import ConvNeXtBase
from tensorflow.keras.layers import Add, Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model

convnext_base = ConvNeXtBase(include_top=False, input_shape=(224, 224, 3), weights='imagenet')

vit_model = vit.vit_b16(image_size=224, activation='softmax', include_top=False, pretrained=True, pretrained_top=False)

for layer in convnext_base.layers:  
    layer.trainable = False

for layer in vit_model.layers:  
    layer.trainable = False

input_tensor = Input(shape=(224, 224, 3))

convnext_output = convnext_base(input_tensor)
vit_output = vit_model(input_tensor)

convnext_output = GlobalAveragePooling2D()(convnext_output)
convnext_output = Dense(1024, activation='relu')(convnext_output)

vit_output = Dense(1024, activation='relu')(vit_output)

fusion_output = Add()([convnext_output, vit_output])
fusion_output = Dense(256, activation='relu')(fusion_output)
output_tensor = Dense(2, activation='softmax')(fusion_output)

fusion_model = Model(inputs=input_tensor, outputs=output_tensor)

fusion_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
                    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy']
                    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-B_16_imagenet21k+imagenet2012.npz
# 347502902/347502902 [==============================] - 1s 0us/step

# %%
fusion_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  convnext_base (Functional)  (None, 7, 7, 1024)           8756646   ['input_3[0][0]']
#                                                           4
#
#  global_average_pooling2d (  (None, 1024)                 0         ['convnext_base[0][0]']
#  GlobalAveragePooling2D)
#
#  vit-b16 (Functional)        (None, 768)                  8579865   ['input_3[0][0]']
#                                                           6
#
#  dense (Dense)               (None, 1024)                 1049600   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 1024)                 787456    ['vit-b16[0][0]']
#
#  add (Add)                   (None, 1024)                 0         ['dense[0][0]',
#                                                                      'dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  262400    ['add[0][0]']
#
#  dense_3 (Dense)             (None, 2)                    514       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 175465090 (669.35 MB)
# Trainable params: 2099970 (8.01 MB)
# Non-trainable params: 173365120 (661.34 MB)
# __________________________________________________________________________________________________

# %%
my_callbacks = [Test_Pred_During_Training(model=fusion_model),
                tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor=0.1, min_delta = 0.01, patience=6),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0.01,patience=20),
                tf.keras.callbacks.ModelCheckpoint("/kaggle/working/my_model.tf", monitor="val_loss", mode="min", save_best_only=True, verbose=1)]

# %%
import time
start = time.time()
history = fusion_model.fit(
    train_dataset,
    batch_size=32,
    epochs=50,
    validation_data=valid_dataset,
    callbacks=[my_callbacks]
)
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717516488.109768      78 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 297/297 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8503
# Epoch 1: val_loss improved from inf to 0.31408, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 313s 937ms/step - loss: 0.3691 - accuracy: 0.8503 - val_loss: 0.3141 - val_accuracy: 0.8615 - lr: 0.0010
# Epoch 2/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8801
# Epoch 2: val_loss improved from 0.31408 to 0.29414, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 264s 888ms/step - loss: 0.2776 - accuracy: 0.8801 - val_loss: 0.2941 - val_accuracy: 0.8746 - lr: 0.0010
# Epoch 3/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.8957
# Epoch 3: val_loss did not improve from 0.29414
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2544 - accuracy: 0.8957 - val_loss: 0.3038 - val_accuracy: 0.8716 - lr: 0.0010
# Epoch 4/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.8925
# Epoch 4: val_loss did not improve from 0.29414
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2520 - accuracy: 0.8925 - val_loss: 0.3047 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 5/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8971
# Epoch 5: val_loss improved from 0.29414 to 0.28070, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 262s 883ms/step - loss: 0.2390 - accuracy: 0.8971 - val_loss: 0.2807 - val_accuracy: 0.8792 - lr: 0.0010
# Epoch 6/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9046
# Epoch 6: val_loss did not improve from 0.28070
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2256 - accuracy: 0.9046 - val_loss: 0.3082 - val_accuracy: 0.8737 - lr: 0.0010
# Epoch 7/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9060
# Epoch 7: val_loss did not improve from 0.28070
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2259 - accuracy: 0.9060 - val_loss: 0.2880 - val_accuracy: 0.8716 - lr: 0.0010
# Epoch 8/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9072
# Epoch 8: val_loss improved from 0.28070 to 0.26880, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 263s 885ms/step - loss: 0.2131 - accuracy: 0.9072 - val_loss: 0.2688 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 9/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9081
# Epoch 9: val_loss did not improve from 0.26880
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2131 - accuracy: 0.9081 - val_loss: 0.3131 - val_accuracy: 0.8569 - lr: 0.0010
# Epoch 10/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2029 - accuracy: 0.9154
# Mean Squared Error : 0.11000
# Weighted F1 Score : 0.890
# Accuracy Score : 89.000 %
# --------------------------------------------------------------------------------
#
# Epoch 10: val_loss did not improve from 0.26880
# 297/297 [==============================] - 253s 851ms/step - loss: 0.2029 - accuracy: 0.9154 - val_loss: 0.2861 - val_accuracy: 0.8767 - lr: 0.0010
# Epoch 11/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9158
# Epoch 11: val_loss did not improve from 0.26880
# 297/297 [==============================] - 209s 704ms/step - loss: 0.2049 - accuracy: 0.9158 - val_loss: 0.2746 - val_accuracy: 0.8801 - lr: 0.0010
# Epoch 12/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9184
# Epoch 12: val_loss improved from 0.26880 to 0.26672, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 264s 889ms/step - loss: 0.1971 - accuracy: 0.9184 - val_loss: 0.2667 - val_accuracy: 0.8918 - lr: 0.0010
# Epoch 13/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9179
# Epoch 13: val_loss improved from 0.26672 to 0.26663, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 263s 885ms/step - loss: 0.1913 - accuracy: 0.9179 - val_loss: 0.2666 - val_accuracy: 0.8847 - lr: 0.0010
# Epoch 14/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9224
# Epoch 14: val_loss did not improve from 0.26663
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1878 - accuracy: 0.9224 - val_loss: 0.2784 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 15/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9303
# Epoch 15: val_loss improved from 0.26663 to 0.24902, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 263s 886ms/step - loss: 0.1671 - accuracy: 0.9303 - val_loss: 0.2490 - val_accuracy: 0.8986 - lr: 1.0000e-04
# Epoch 16/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9332
# Epoch 16: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1625 - accuracy: 0.9332 - val_loss: 0.2536 - val_accuracy: 0.8969 - lr: 1.0000e-04
# Epoch 17/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9358
# Epoch 17: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1584 - accuracy: 0.9358 - val_loss: 0.2547 - val_accuracy: 0.8969 - lr: 1.0000e-04
# Epoch 18/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9363
# Epoch 18: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1542 - accuracy: 0.9363 - val_loss: 0.2537 - val_accuracy: 0.8994 - lr: 1.0000e-04
# Epoch 19/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9369
# Epoch 19: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1560 - accuracy: 0.9369 - val_loss: 0.2547 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 20/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9372
# Mean Squared Error : 0.10550
# Weighted F1 Score : 0.894
# Accuracy Score : 89.450 %
# --------------------------------------------------------------------------------
#
# Epoch 20: val_loss did not improve from 0.24902
# 297/297 [==============================] - 243s 817ms/step - loss: 0.1530 - accuracy: 0.9372 - val_loss: 0.2521 - val_accuracy: 0.8981 - lr: 1.0000e-04
# Epoch 21/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9362
# Epoch 21: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1504 - accuracy: 0.9362 - val_loss: 0.2571 - val_accuracy: 0.9003 - lr: 1.0000e-04
# Epoch 22/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9397
# Epoch 22: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1488 - accuracy: 0.9397 - val_loss: 0.2560 - val_accuracy: 0.9019 - lr: 1.0000e-05
# Epoch 23/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9401
# Epoch 23: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1407 - accuracy: 0.9401 - val_loss: 0.2556 - val_accuracy: 0.9011 - lr: 1.0000e-05
# Epoch 24/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9370
# Epoch 24: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1483 - accuracy: 0.9370 - val_loss: 0.2542 - val_accuracy: 0.9024 - lr: 1.0000e-05
# Epoch 25/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9400
# Epoch 25: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1433 - accuracy: 0.9400 - val_loss: 0.2545 - val_accuracy: 0.9011 - lr: 1.0000e-05
# Epoch 26/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9400
# Epoch 26: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1447 - accuracy: 0.9400 - val_loss: 0.2544 - val_accuracy: 0.9007 - lr: 1.0000e-05
# Epoch 27/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9411
# Epoch 27: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 703ms/step - loss: 0.1420 - accuracy: 0.9411 - val_loss: 0.2551 - val_accuracy: 0.9019 - lr: 1.0000e-05
# Epoch 28/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9384
# Epoch 28: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1454 - accuracy: 0.9384 - val_loss: 0.2552 - val_accuracy: 0.9015 - lr: 1.0000e-06
# Epoch 29/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9381
# Epoch 29: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1435 - accuracy: 0.9381 - val_loss: 0.2552 - val_accuracy: 0.9024 - lr: 1.0000e-06
# Epoch 30/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9396
# Mean Squared Error : 0.10700
# Weighted F1 Score : 0.893
# Accuracy Score : 89.300 %
# --------------------------------------------------------------------------------
#
# Epoch 30: val_loss did not improve from 0.24902
# 297/297 [==============================] - 243s 817ms/step - loss: 0.1466 - accuracy: 0.9396 - val_loss: 0.2553 - val_accuracy: 0.9011 - lr: 1.0000e-06
# Epoch 31/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9407
# Epoch 31: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1459 - accuracy: 0.9407 - val_loss: 0.2553 - val_accuracy: 0.9007 - lr: 1.0000e-06
# Epoch 32/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9389
# Epoch 32: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1454 - accuracy: 0.9389 - val_loss: 0.2553 - val_accuracy: 0.9007 - lr: 1.0000e-06
# Epoch 33/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9422
# Epoch 33: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1425 - accuracy: 0.9422 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-06
# Epoch 34/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9397
# Epoch 34: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1417 - accuracy: 0.9397 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 35/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9424
# Epoch 35: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1434 - accuracy: 0.9424 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 36/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9419
# Epoch 36: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1429 - accuracy: 0.9419 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 37/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9424
# Epoch 37: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1393 - accuracy: 0.9424 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 38/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9410
# Epoch 38: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1404 - accuracy: 0.9410 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 39/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9435
# Epoch 39: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1392 - accuracy: 0.9435 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-07
# Epoch 40/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9396
# Mean Squared Error : 0.10750
# Weighted F1 Score : 0.892
# Accuracy Score : 89.250 %
# --------------------------------------------------------------------------------
#
# Epoch 40: val_loss did not improve from 0.24902
# 297/297 [==============================] - 243s 817ms/step - loss: 0.1432 - accuracy: 0.9396 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 41/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9422
# Epoch 41: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1414 - accuracy: 0.9422 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 42/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9425
# Epoch 42: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1423 - accuracy: 0.9425 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 43/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9411
# Epoch 43: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1416 - accuracy: 0.9411 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 44/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9437
# Epoch 44: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1414 - accuracy: 0.9437 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 45/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9409
# Epoch 45: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1441 - accuracy: 0.9409 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-08
# Epoch 46/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9422
# Epoch 46: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 703ms/step - loss: 0.1420 - accuracy: 0.9422 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-09
# Epoch 47/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9396
# Epoch 47: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1419 - accuracy: 0.9396 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-09
# Epoch 48/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9417
# Epoch 48: val_loss did not improve from 0.24902
# 297/297 [==============================] - 209s 704ms/step - loss: 0.1401 - accuracy: 0.9417 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-09
# Epoch 49/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9411
# Epoch 49: val_loss did not improve from 0.24902
# 297/297 [==============================] - 210s 704ms/step - loss: 0.1388 - accuracy: 0.9411 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-09
# Epoch 50/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9403
# Mean Squared Error : 0.10750
# Weighted F1 Score : 0.892
# Accuracy Score : 89.250 %
# --------------------------------------------------------------------------------
#
# Epoch 50: val_loss did not improve from 0.24902
# 297/297 [==============================] - 243s 817ms/step - loss: 0.1450 - accuracy: 0.9403 - val_loss: 0.2555 - val_accuracy: 0.9007 - lr: 1.0000e-09
# Total time:  11573.326999425888 seconds

# %% [markdown]
# # <span style="color:#e74c3c;"> Training</span> Results

# %%
# Print training results
print("Training Results:")
print("Loss:", history.history['loss'][-1])
print("Accuracy:", history.history['accuracy'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Training Results:
# Loss: 0.14497053623199463
# Accuracy: 0.9403346180915833
# Validation Loss: 0.255513995885849
# Validation Accuracy: 0.9006733894348145

# %%
fig, axs = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

axs.grid(linestyle='dashdot')
axs.plot(history.history['loss'])
axs.plot(history.history['val_loss'])
axs.set_xlabel('epochs', fontsize=10)
axs.set_ylabel('Loss', fontsize=10)
axs.legend(['Train Loss', 'Validation Loss'], fontsize=10)
axs.set_ylim(0, 1)
print(f'Loss: Train Loss = {history.history["loss"][-1]:.4f}, Validation Loss = {history.history["val_loss"][-1]:.4f}')
# Out:
# Loss: Train Loss = 0.1450, Validation Loss = 0.2555

# %%
fig, axs = plt.subplots(1,1, figsize = (5, 5), dpi = 100)
axs.grid(linestyle = 'dashdot')
axs.plot(history.history['accuracy'])
axs.plot(history.history['val_accuracy'])
axs.set_xlabel('epochs', fontsize = 10)
axs.legend(['train accuracy', 'validation accuracy'], fontsize = 10)
axs.set_ylim(0, 1)
print(f'Accuracy: Train Accuracy = {history.history["accuracy"][-1]:.4f}, Validation Accuracy = {history.history["val_accuracy"][-1]:.4f}')
# Out:
# Accuracy: Train Accuracy = 0.9403, Validation Accuracy = 0.9007

# %% [markdown]
# # <span style="color:#e74c3c;"> Test </span> Prediction

# %%
# Predictions and scores
test_pred = fusion_model.predict(test_dataset)
test_pred = np.argmax(test_pred, axis = 1)

mse = mean_squared_error(test_data['label'], test_pred)
f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
acc = accuracy_score(test_data['label'], test_pred)

print('Mean Squared Error : {0:.5f}'.format(mse))
print('Weighted F1 Score : {0:.3f}'.format(f1))
print('Accuracy Score : {0:.3f} %'.format(acc*100))
# Out:
# 63/63 [==============================] - 34s 534ms/step
# Mean Squared Error : 0.10750
# Weighted F1 Score : 0.892
# Accuracy Score : 89.250 %

# %% [markdown]
# # <span style="color:#e74c3c;"> Classification </span> Report

# %%
clf = classification_report(test_data['label'], test_pred, target_names = list(classes.values()))
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.85      0.95      0.90      1000
#    Malignant       0.94      0.84      0.89      1000
#
#     accuracy                           0.89      2000
#    macro avg       0.90      0.89      0.89      2000
# weighted avg       0.90      0.89      0.89      2000

# %% [markdown]
# # <span style="color:#e74c3c;"> Confusion </span> Matrix

# %%
cm = confusion_matrix(test_data['label'], test_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels = list(classes.values()))

fig, ax = plt.subplots(figsize=(5,5))
cmd.plot(ax=ax,  cmap = 'Blues', colorbar = False)

# %% [markdown]
# # <span style="color:#e74c3c;"> Test</span> Results

# %%
# Evaluate the model on the test set
test_loss, test_acc = fusion_model.evaluate(test_dataset)

# Print test results
print("\nTest Results:")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 63/63 [==============================] - 34s 536ms/step - loss: 0.2564 - accuracy: 0.8925
#
# Test Results:
# Test Loss: 0.2564472556114197
# Test Accuracy: 0.8924999833106995

# %%
import matplotlib.pyplot as plt

# Create a bar chart
x = ['Test Loss', 'Test Accuracy']
y = [test_loss, test_acc]

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(x, y)

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Model Evaluation on Test Set')

# Add value labels to the bars
for i, v in enumerate(y):
    ax.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # <span style="color:#e74c3c;"> Test Set </span> Predictions

# %%
test_take1 =  test_dataset.take(-1)
test_take1_ = list(test_take1)

# A function that creating 5 random images in the test set and predictions

# Red title -> a false prediction
# Green title -> a true prediction

def random_test_sample_with_prediction(SEED):
    
    idxs = np.random.default_rng(seed=SEED).permutation(len(test_pred))[:5]
    batch_idx = idxs // BATCH_SIZE
    image_idx = idxs - batch_idx * BATCH_SIZE
    idx = idxs

    fig, axs = plt.subplots(1, 5, figsize=(12, 12), dpi=150)

    for i in range(5):
        img = test_take1_[batch_idx[i]][0][image_idx[i]]
        label = test_take1_[batch_idx[i]][1][image_idx[i]].numpy()
        pred_label = int(test_pred[idx[i]])
        pred_prob = fusion_model.predict(tf.expand_dims(img, axis=0))[0][pred_label]

        if pred_label == label:
            axs[i].imshow(img, cmap='gray') 
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='green')
        else:
            axs[i].imshow(img, cmap='gray')
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='red')

# %%
# Red title -> a false prediction
# Green title -> a true prediction

random_test_sample_with_prediction(21)
random_test_sample_with_prediction(204)
random_test_sample_with_prediction(293)
# Out:
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step

# %%
loaded_model = tf.keras.models.load_model('/kaggle/working/my_model.tf')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# 5742
test_image_path = '/kaggle/input/melanoma-cancer-dataset/test/Malignant/5742.jpg'

test_image = cv2.imread(test_image_path)
test_image = cv2.resize(test_image, (224, 224))
test_image_display = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
test_image_normalized = test_image / 255.0
test_image_normalized = np.expand_dims(test_image_normalized, axis=0)

predictions = loaded_model.predict(test_image_normalized)
predicted_class_index = np.argmax(predictions)
if predicted_class_index == 0:
    predicted_class = 'Benign'
else:
    predicted_class = 'Malignant'

predicted_accuracy = np.max(predictions) *100

# if predicted_class_index == 1:
#     bounding_box = [50, 70, 150, 120]
#     cv2.rectangle(test_image_display, (bounding_box[0], bounding_box[1]), (bounding_box[2], bounding_box[3]), (0, 255, 0), 2)

plt.imshow(test_image_display)
plt.title(f"{predicted_class} ({predicted_accuracy:.2f}% accuracy)")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 10s 10s/step
