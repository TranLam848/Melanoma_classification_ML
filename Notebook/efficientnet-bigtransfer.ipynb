# %%
pip install keras==2.15.0
# Out:
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.0 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# Successfully installed keras-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2024-06-03 13:12:29.269988: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 13:12:29.270085: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 13:12:29.395588: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.15.0
# 2.15.0

# %%
# Importing dependencies

import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import *
import keras
from tensorflow.keras.callbacks import Callback

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score,RocCurveDisplay

SEED = 8
IMG_SIZE = 224, 224
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

# %% [markdown]
# # <span style="color:#e74c3c;"> Reading </span> Data

# %%
# creating main dataframe contains image paths and their classes.

def create_images_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    for i in images:
        full_path.append(os.path.join(path, i))
    return full_path


classes = {0: 'Benign', 1: 'Malignant'}

train_bening_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Benign')
train_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Malignant')

full_data = pd.concat([pd.DataFrame({'image' : train_bening_imgs, 'label': 0 }),
                      pd.DataFrame({'image' : train_malignant_imgs, 'label': 1 })])
# shuffling dataset
full_data = full_data.sample(frac = 1, ignore_index = True, random_state = SEED)

# train and valid splitting
train_data, valid_data = train_test_split(full_data, test_size = 0.2, stratify = full_data['label'])

train_data = train_data.reset_index(drop = True)
valid_data = valid_data.reset_index(drop = True)

# test dataframe
test_bening_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Benign')
test_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Malignant')

test_data = pd.concat([pd.DataFrame({'image' : test_bening_imgs, 'label': 0 }),
                       pd.DataFrame({'image' : test_malignant_imgs, 'label': 1 })])
test_data = test_data.sample(frac = 1, ignore_index = True, random_state = SEED)


print('total train images \t{0}'.format(train_data.shape[0]))
print('total valid images \t{0}'.format(valid_data.shape[0]))
print('total test images \t{0}'.format(test_data.shape[0]))
# Out:
# total train images 	9503
# total valid images 	2376
# total test images 	2000

# %% [markdown]
# # <span style="color:#e74c3c;"> Creating </span> tf.data Pipeline

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Print 25 random samples from the training data with inferno colormap
plt.figure(figsize=(15, 15))

for i in range(25):
    ax = plt.subplot(5, 5, i+1)
    random_index = np.random.randint(0, train_data.shape[0])
    img_path = train_data.loc[random_index, 'image']
    img = Image.open(img_path)
    plt.imshow(img)
    ax.set_title(f"Label: {classes[train_data.loc[random_index, 'label']]}")
    ax.axis('off')

plt.show()

# %%
# Reading -> Resizing -> Normalization
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_png(img, channels = 3)
    img = tf.image.resize(img, size =(IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0
    
    
    return img, label


# Data augmentation 
img_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation((-0.3, 0.3), interpolation="bilinear"),
    RandomContrast(0.03),
    RandomCrop(*IMG_SIZE)])

# %%
# Creating dataset loaders and tf.datasets

train_loader = tf.data.Dataset.from_tensor_slices((train_data['image'], train_data['label']))
train_dataset = (train_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .batch(BATCH_SIZE)
                 .map(lambda img, label: (img_augmentation(img), label), num_parallel_calls =AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_data['image'], valid_data['label']))
valid_dataset = (valid_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

test_loader = tf.data.Dataset.from_tensor_slices((test_data['image'], test_data['label']))
test_dataset = (test_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

# %%
# Display original and augmented image for the first sample
def display_sample_images(dataset):
    for images, labels in dataset.take(1):
        # Display original image
        original_image = images[0].numpy()
        
        # Apply augmentation
        augmented_image = img_augmentation(images[0:1], training=True)[0].numpy()
        
        # Plotting
        plt.figure(figsize=(8, 4))
        
        # Original image
        plt.subplot(1, 2, 1)
        plt.title("Original Image")
        plt.imshow(original_image,cmap='inferno')
        plt.axis("off")
        
        # Augmented image
        plt.subplot(1, 2, 2)
        plt.title("Augmented Image")
        plt.imshow(augmented_image,cmap='inferno')
        plt.axis("off")
        
        plt.show()
        break

# Display original and augmented images from train dataset
display_sample_images(train_dataset)

# %%
# a custom callback for evaluation of test set during training each 10 loop
class Test_Pred_During_Training(Callback):
    
    def __init__(self, model):
        self.model = model
        
    def on_epoch_end(self, epochs, logs = None ):
        try:
            if (epochs+1) % 10 == 0:
                test_pred = self.model.predict(test_dataset, verbose = 0)
                test_pred = np.argmax(test_pred, axis = 1)

                mse = mean_squared_error(test_data['label'], test_pred)
                f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
                acc = accuracy_score(test_data['label'], test_pred)

                print('\nMean Squared Error : {0:.5f}'.format(mse))
                print('Weighted F1 Score : {0:.3f}'.format(f1))
                print('Accuracy Score : {0:.3f} %'.format(acc*100))

                print("--"*40)
        except ValueError:
            pass

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.layers import Concatenate, Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model

# Tạo mô hình EfficientNet
efficientnet = tf.keras.applications.EfficientNetB0(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# Tạo mô hình Bit từ URL
bit_model_url = "https://www.kaggle.com/models/google/bit/TensorFlow2/m-r152x4/1"
bit_model = hub.KerasLayer(bit_model_url, trainable=False)

# Đóng băng các layer trong mô hình EfficientNet
for layer in efficientnet.layers:
    layer.trainable = False

# Tạo input tensor
input_tensor = Input(shape=(224, 224, 3))

# Lấy đầu ra của EfficientNet
efficientnet_output = efficientnet(input_tensor)

# Áp dụng Global Average Pooling (GAP) cho đầu ra của EfficientNet
efficientnet_output = GlobalAveragePooling2D()(efficientnet_output)

# Lấy đầu ra của mô hình Bit
bit_output = bit_model(input_tensor)

# Thêm một lớp Dense cho đầu ra của mô hình Bit
bit_output = Dense(2048, activation='relu')(bit_output)

# Kết hợp các đầu ra bằng lớp Concatenate hoặc Add
fusion_output = Concatenate()([efficientnet_output, bit_output])

fusion_output = Dense(256, activation='relu')(fusion_output)
fusion_output = Dense(2, activation='softmax')(fusion_output)
fusion_model = Model(inputs=input_tensor, outputs=fusion_output)

fusion_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
                    loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                    metrics=['accuracy'])

# Hiển thị cấu trúc của mô hình
fusion_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step
# Attaching model 'google/bit/tensorflow2/m-r152x4/1' to your Kaggle notebook...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  efficientnetb0 (Functional  (None, 7, 7, 1280)           4049571   ['input_2[0][0]']
#  )
#
#  keras_layer (KerasLayer)    (None, 8192)                 9283402   ['input_2[0][0]']
#                                                           24
#
#  global_average_pooling2d (  (None, 1280)                 0         ['efficientnetb0[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2048)                 1677926   ['keras_layer[0][0]']
#                                                           4
#
#  concatenate (Concatenate)   (None, 3328)                 0         ['global_average_pooling2d[0][
#                                                                     0]',
#                                                                      'dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  852224    ['concatenate[0][0]']
#
#  dense_2 (Dense)             (None, 2)                    514       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 950021797 (3.54 GB)
# Trainable params: 17632002 (67.26 MB)
# Non-trainable params: 932389795 (3.47 GB)
# __________________________________________________________________________________________________

# %%
my_callbacks = [Test_Pred_During_Training(fusion_model),
                tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor=0.1, min_delta = 0.01, patience=6),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0.01,patience=20),
                tf.keras.callbacks.ModelCheckpoint("/kaggle/working/my_model.tf", monitor="val_loss", mode="min", save_best_only=True, verbose=1)]

# %%
import time
start = time.time()
history = fusion_model.fit(
    train_dataset,
    batch_size=32,
    epochs=50,
    validation_data=valid_dataset,
    callbacks=my_callbacks
)
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# 2024-06-03 13:14:49.132320: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717420502.631610      81 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 297/297 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8453
# Epoch 1: val_loss improved from inf to 0.26374, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 863s 3s/step - loss: 0.3499 - accuracy: 0.8453 - val_loss: 0.2637 - val_accuracy: 0.8880 - lr: 0.0010
# Epoch 2/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.8868
# Epoch 2: val_loss did not improve from 0.26374
# 297/297 [==============================] - 713s 2s/step - loss: 0.2678 - accuracy: 0.8868 - val_loss: 0.2683 - val_accuracy: 0.8754 - lr: 0.0010
# Epoch 3/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.8930
# Epoch 3: val_loss improved from 0.26374 to 0.24190, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 802s 3s/step - loss: 0.2500 - accuracy: 0.8930 - val_loss: 0.2419 - val_accuracy: 0.8990 - lr: 0.0010
# Epoch 4/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9042
# Epoch 4: val_loss did not improve from 0.24190
# 297/297 [==============================] - 713s 2s/step - loss: 0.2344 - accuracy: 0.9042 - val_loss: 0.2599 - val_accuracy: 0.8784 - lr: 0.0010
# Epoch 5/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9058
# Epoch 5: val_loss did not improve from 0.24190
# 297/297 [==============================] - 713s 2s/step - loss: 0.2241 - accuracy: 0.9058 - val_loss: 0.2423 - val_accuracy: 0.8939 - lr: 0.0010
# Epoch 6/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2140 - accuracy: 0.9124
# Epoch 6: val_loss improved from 0.24190 to 0.23168, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 799s 3s/step - loss: 0.2140 - accuracy: 0.9124 - val_loss: 0.2317 - val_accuracy: 0.9003 - lr: 0.0010
# Epoch 7/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9122
# Epoch 7: val_loss did not improve from 0.23168
# 297/297 [==============================] - 713s 2s/step - loss: 0.2110 - accuracy: 0.9122 - val_loss: 0.2319 - val_accuracy: 0.9019 - lr: 0.0010
# Epoch 8/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9183
# Epoch 8: val_loss did not improve from 0.23168
# 297/297 [==============================] - 713s 2s/step - loss: 0.1990 - accuracy: 0.9183 - val_loss: 0.2443 - val_accuracy: 0.8956 - lr: 0.0010
# Epoch 9/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9211
# Epoch 9: val_loss did not improve from 0.23168
# 297/297 [==============================] - 713s 2s/step - loss: 0.1931 - accuracy: 0.9211 - val_loss: 0.2466 - val_accuracy: 0.8880 - lr: 0.0010
# Epoch 10/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9209
# Mean Squared Error : 0.08450
# Weighted F1 Score : 0.915
# Accuracy Score : 91.550 %
# --------------------------------------------------------------------------------
#
# Epoch 10: val_loss did not improve from 0.23168
# 297/297 [==============================] - 850s 3s/step - loss: 0.1920 - accuracy: 0.9209 - val_loss: 0.2319 - val_accuracy: 0.8994 - lr: 0.0010
# Epoch 11/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9270
# Epoch 11: val_loss improved from 0.23168 to 0.23044, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 806s 3s/step - loss: 0.1827 - accuracy: 0.9270 - val_loss: 0.2304 - val_accuracy: 0.8994 - lr: 0.0010
# Epoch 12/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9251
# Epoch 12: val_loss did not improve from 0.23044
# 297/297 [==============================] - 713s 2s/step - loss: 0.1816 - accuracy: 0.9251 - val_loss: 0.2320 - val_accuracy: 0.8994 - lr: 0.0010
# Epoch 13/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9302
# Epoch 13: val_loss improved from 0.23044 to 0.22156, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 801s 3s/step - loss: 0.1724 - accuracy: 0.9302 - val_loss: 0.2216 - val_accuracy: 0.9120 - lr: 1.0000e-04
# Epoch 14/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9340
# Epoch 14: val_loss improved from 0.22156 to 0.22083, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 806s 3s/step - loss: 0.1682 - accuracy: 0.9340 - val_loss: 0.2208 - val_accuracy: 0.9129 - lr: 1.0000e-04
# Epoch 15/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9336
# Epoch 15: val_loss improved from 0.22083 to 0.22005, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 803s 3s/step - loss: 0.1659 - accuracy: 0.9336 - val_loss: 0.2201 - val_accuracy: 0.9125 - lr: 1.0000e-04
# Epoch 16/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9324
# Epoch 16: val_loss did not improve from 0.22005
# 297/297 [==============================] - 713s 2s/step - loss: 0.1678 - accuracy: 0.9324 - val_loss: 0.2207 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 17/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9363
# Epoch 17: val_loss improved from 0.22005 to 0.21985, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 803s 3s/step - loss: 0.1632 - accuracy: 0.9363 - val_loss: 0.2199 - val_accuracy: 0.9146 - lr: 1.0000e-04
# Epoch 18/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9391
# Epoch 18: val_loss improved from 0.21985 to 0.21981, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 806s 3s/step - loss: 0.1616 - accuracy: 0.9391 - val_loss: 0.2198 - val_accuracy: 0.9116 - lr: 1.0000e-04
# Epoch 19/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9349
# Epoch 19: val_loss improved from 0.21981 to 0.21932, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 808s 3s/step - loss: 0.1622 - accuracy: 0.9349 - val_loss: 0.2193 - val_accuracy: 0.9133 - lr: 1.0000e-04
# Epoch 20/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9357
# Mean Squared Error : 0.10400
# Weighted F1 Score : 0.896
# Accuracy Score : 89.600 %
# --------------------------------------------------------------------------------
#
# Epoch 20: val_loss improved from 0.21932 to 0.21916, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 928s 3s/step - loss: 0.1623 - accuracy: 0.9357 - val_loss: 0.2192 - val_accuracy: 0.9129 - lr: 1.0000e-05
# Epoch 21/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9383
# Epoch 21: val_loss improved from 0.21916 to 0.21906, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 801s 3s/step - loss: 0.1598 - accuracy: 0.9383 - val_loss: 0.2191 - val_accuracy: 0.9137 - lr: 1.0000e-05
# Epoch 22/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9392
# Epoch 22: val_loss did not improve from 0.21906
# 297/297 [==============================] - 713s 2s/step - loss: 0.1592 - accuracy: 0.9392 - val_loss: 0.2191 - val_accuracy: 0.9129 - lr: 1.0000e-05
# Epoch 23/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9385
# Epoch 23: val_loss improved from 0.21906 to 0.21901, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 807s 3s/step - loss: 0.1571 - accuracy: 0.9385 - val_loss: 0.2190 - val_accuracy: 0.9137 - lr: 1.0000e-05
# Epoch 24/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9340
# Epoch 24: val_loss improved from 0.21901 to 0.21898, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 807s 3s/step - loss: 0.1622 - accuracy: 0.9340 - val_loss: 0.2190 - val_accuracy: 0.9137 - lr: 1.0000e-05
# Epoch 25/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9373
# Epoch 25: val_loss did not improve from 0.21898
# 297/297 [==============================] - 713s 2s/step - loss: 0.1565 - accuracy: 0.9373 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-05
# Epoch 26/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9367
# Epoch 26: val_loss did not improve from 0.21898
# 297/297 [==============================] - 713s 2s/step - loss: 0.1603 - accuracy: 0.9367 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 27/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9352
# Epoch 27: val_loss did not improve from 0.21898
# 297/297 [==============================] - 713s 2s/step - loss: 0.1630 - accuracy: 0.9352 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 28/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9358
# Epoch 28: val_loss did not improve from 0.21898
# 297/297 [==============================] - 713s 2s/step - loss: 0.1603 - accuracy: 0.9358 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 29/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9371
# Epoch 29: val_loss improved from 0.21898 to 0.21898, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 803s 3s/step - loss: 0.1596 - accuracy: 0.9371 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 30/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9384
# Mean Squared Error : 0.10100
# Weighted F1 Score : 0.899
# Accuracy Score : 89.900 %
# --------------------------------------------------------------------------------
#
# Epoch 30: val_loss improved from 0.21898 to 0.21897, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 926s 3s/step - loss: 0.1600 - accuracy: 0.9384 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 31/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9358
# Epoch 31: val_loss did not improve from 0.21897
# 297/297 [==============================] - 714s 2s/step - loss: 0.1597 - accuracy: 0.9358 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-06
# Epoch 32/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9372
# Epoch 32: val_loss did not improve from 0.21897
# 297/297 [==============================] - 714s 2s/step - loss: 0.1609 - accuracy: 0.9372 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 33/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 0.9361
# Epoch 33: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1590 - accuracy: 0.9361 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 34/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9385
# Epoch 34: val_loss did not improve from 0.21897
# 297/297 [==============================] - 714s 2s/step - loss: 0.1573 - accuracy: 0.9385 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 35/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9381
# Epoch 35: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1592 - accuracy: 0.9381 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 36/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9389
# Epoch 36: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1587 - accuracy: 0.9389 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 37/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9373
# Epoch 37: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1579 - accuracy: 0.9373 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-07
# Epoch 38/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9392
# Epoch 38: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1575 - accuracy: 0.9392 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 39/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9371
# Epoch 39: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1615 - accuracy: 0.9371 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 40/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9375
# Mean Squared Error : 0.10000
# Weighted F1 Score : 0.900
# Accuracy Score : 90.000 %
# --------------------------------------------------------------------------------
#
# Epoch 40: val_loss did not improve from 0.21897
# 297/297 [==============================] - 837s 3s/step - loss: 0.1586 - accuracy: 0.9375 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 41/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9370
# Epoch 41: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1593 - accuracy: 0.9370 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 42/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9351
# Epoch 42: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1596 - accuracy: 0.9351 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 43/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9358
# Epoch 43: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1593 - accuracy: 0.9358 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-08
# Epoch 44/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9349
# Epoch 44: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1606 - accuracy: 0.9349 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 45/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9382
# Epoch 45: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1606 - accuracy: 0.9382 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 46/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9380
# Epoch 46: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1600 - accuracy: 0.9380 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 47/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9355
# Epoch 47: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1608 - accuracy: 0.9355 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 48/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9357
# Epoch 48: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1626 - accuracy: 0.9357 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 49/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9395
# Epoch 49: val_loss did not improve from 0.21897
# 297/297 [==============================] - 713s 2s/step - loss: 0.1602 - accuracy: 0.9395 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-09
# Epoch 50/50
# 297/297 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9375
# Mean Squared Error : 0.10000
# Weighted F1 Score : 0.900
# Accuracy Score : 90.000 %
# --------------------------------------------------------------------------------
#
# Epoch 50: val_loss did not improve from 0.21897
# 297/297 [==============================] - 837s 3s/step - loss: 0.1604 - accuracy: 0.9375 - val_loss: 0.2190 - val_accuracy: 0.9125 - lr: 1.0000e-10
# Total time:  38483.98291683197 seconds

# %% [markdown]
# # <span style="color:#e74c3c;"> Training</span> Results

# %%
# Print training results
print("Training Results:")
print("Loss:", history.history['loss'][-1])
print("Accuracy:", history.history['accuracy'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Training Results:
# Loss: 0.1603652387857437
# Accuracy: 0.9374934434890747
# Validation Loss: 0.2189861536026001
# Validation Accuracy: 0.9124578833580017

# %%
fig, axs = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

axs.grid(linestyle='dashdot')
axs.plot(history.history['loss'])
axs.plot(history.history['val_loss'])
axs.set_xlabel('epochs', fontsize=10)
axs.set_ylabel('Loss', fontsize=10)
axs.legend(['Train Loss', 'Validation Loss'], fontsize=10)
axs.set_ylim(0, 1)
print(f'Loss: Train Loss = {history.history["loss"][-1]:.4f}, Validation Loss = {history.history["val_loss"][-1]:.4f}')
# Out:
# Loss: Train Loss = 0.1604, Validation Loss = 0.2190

# %%
fig, axs = plt.subplots(1,1, figsize = (5, 5), dpi = 100)
axs.grid(linestyle = 'dashdot')
axs.plot(history.history['accuracy'])
axs.plot(history.history['val_accuracy'])
axs.set_xlabel('epochs', fontsize = 10)
axs.legend(['train accuracy', 'validation accuracy'], fontsize = 10)
axs.set_ylim(0, 1)
print(f'Accuracy: Train Accuracy = {history.history["accuracy"][-1]:.4f}, Validation Accuracy = {history.history["val_accuracy"][-1]:.4f}')
# Out:
# Accuracy: Train Accuracy = 0.9375, Validation Accuracy = 0.9125

# %% [markdown]
# # <span style="color:#e74c3c;"> Test </span> Prediction

# %%
# Predictions and scores
test_pred = fusion_model.predict(test_dataset)
test_pred = np.argmax(test_pred, axis = 1)

mse = mean_squared_error(test_data['label'], test_pred)
f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
acc = accuracy_score(test_data['label'], test_pred)

print('Mean Squared Error : {0:.5f}'.format(mse))
print('Weighted F1 Score : {0:.3f}'.format(f1))
print('Accuracy Score : {0:.3f} %'.format(acc*100))
# Out:
# 63/63 [==============================] - 124s 2s/step
# Mean Squared Error : 0.10000
# Weighted F1 Score : 0.900
# Accuracy Score : 90.000 %

# %% [markdown]
# # <span style="color:#e74c3c;"> Classification </span> Report

# %%
clf = classification_report(test_data['label'], test_pred, target_names = list(classes.values()))
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.88      0.93      0.90      1000
#    Malignant       0.92      0.87      0.90      1000
#
#     accuracy                           0.90      2000
#    macro avg       0.90      0.90      0.90      2000
# weighted avg       0.90      0.90      0.90      2000

# %% [markdown]
# # <span style="color:#e74c3c;"> Confusion </span> Matrix

# %%
cm = confusion_matrix(test_data['label'], test_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels = list(classes.values()))

fig, ax = plt.subplots(figsize=(5,5))
cmd.plot(ax=ax,  cmap = 'Blues', colorbar = False)

# %% [markdown]
# # <span style="color:#e74c3c;"> Test</span> Results

# %%
# Evaluate the model on the test set
test_loss, test_acc = fusion_model.evaluate(test_dataset)

# Print test results
print("\nTest Results:")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 63/63 [==============================] - 124s 2s/step - loss: 0.2442 - accuracy: 0.9000
#
# Test Results:
# Test Loss: 0.2441815882921219
# Test Accuracy: 0.8999999761581421

# %%
import matplotlib.pyplot as plt

# Create a bar chart
x = ['Test Loss', 'Test Accuracy']
y = [test_loss, test_acc]

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(x, y)

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Model Evaluation on Test Set')

# Add value labels to the bars
for i, v in enumerate(y):
    ax.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # <span style="color:#e74c3c;"> Test Set </span> Predictions

# %%
test_take1 =  test_dataset.take(-1)
test_take1_ = list(test_take1)

# A function that creating 5 random images in the test set and predictions

# Red title -> a false prediction
# Green title -> a true prediction

def random_test_sample_with_prediction(SEED):
    
    idxs = np.random.default_rng(seed=SEED).permutation(len(test_pred))[:5]
    batch_idx = idxs // BATCH_SIZE
    image_idx = idxs - batch_idx * BATCH_SIZE
    idx = idxs

    fig, axs = plt.subplots(1, 5, figsize=(12, 12), dpi=150)

    for i in range(5):
        img = test_take1_[batch_idx[i]][0][image_idx[i]]
        label = test_take1_[batch_idx[i]][1][image_idx[i]].numpy()
        pred_label = int(test_pred[idx[i]])
        pred_prob = fusion_model.predict(tf.expand_dims(img, axis=0))[0][pred_label]

        if pred_label == label:
            axs[i].imshow(img, cmap='gray') 
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='green')
        else:
            axs[i].imshow(img, cmap='gray')
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='red')

# %%
# Red title -> a false prediction
# Green title -> a true prediction

random_test_sample_with_prediction(11)
random_test_sample_with_prediction(104)
random_test_sample_with_prediction(193)
# Out:
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 185ms/step

# %%
import tensorflow as tf

# Load the saved model
loaded_model = tf.keras.models.load_model('/kaggle/working/my_model.tf')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# 5742
test_image_path = '/kaggle/input/melanoma-cancer-dataset/test/Malignant/5742.jpg'

test_image = cv2.imread(test_image_path)
test_image = cv2.resize(test_image, (224, 224))
test_image_display = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
test_image_normalized = test_image / 255.0
test_image_normalized = np.expand_dims(test_image_normalized, axis=0)

predictions = loaded_model.predict(test_image_normalized)
predicted_class_index = np.argmax(predictions)
if predicted_class_index == 0:
    predicted_class = 'Benign'
else:
    predicted_class = 'Malignant'

predicted_accuracy = np.max(predictions) *100

# if predicted_class_index == 1:
#     bounding_box = [50, 70, 150, 120]
#     cv2.rectangle(test_image_display, (bounding_box[0], bounding_box[1]), (bounding_box[2], bounding_box[3]), (0, 255, 0), 2)

plt.imshow(test_image_display)
plt.title(f"{predicted_class} ({predicted_accuracy:.2f}% accuracy)")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 7s 7s/step
