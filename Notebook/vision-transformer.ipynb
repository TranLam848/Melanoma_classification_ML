# %%
pip install keras==2.15.0
# Out:
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.8 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# Successfully installed keras-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2024-06-06 16:44:43.719569: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 16:44:43.719688: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 16:44:43.855802: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.15.0
# 2.15.0

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import *
import keras
from tensorflow.keras.callbacks import Callback

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score,RocCurveDisplay

SEED = 42
IMG_SIZE = 224, 224
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

# %%
# creating main dataframe contains image paths and their classes.

def create_images_list(path):
    full_path = []
    images = sorted(os.listdir(path))
    for i in images:
        full_path.append(os.path.join(path, i))
    return full_path


classes = {0: 'Benign', 1: 'Malignant'}

train_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Benign')
train_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/train/Malignant')

full_data = pd.concat([pd.DataFrame({'image' : train_benign_imgs, 'label': 0 }),
                      pd.DataFrame({'image' : train_malignant_imgs, 'label': 1 })])
# shuffling dataset
full_data = full_data.sample(frac = 1, ignore_index = True, random_state = SEED)

# train and valid splitting
train_data, valid_data = train_test_split(full_data, test_size = 0.2, stratify = full_data['label'])

train_data = train_data.reset_index(drop = True)
valid_data = valid_data.reset_index(drop = True)

# test dataframe
test_benign_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Benign')
test_malignant_imgs = create_images_list('/kaggle/input/melanoma-cancer-dataset/test/Malignant')

test_data = pd.concat([pd.DataFrame({'image' : test_benign_imgs, 'label': 0 }),
                       pd.DataFrame({'image' : test_malignant_imgs, 'label': 1 })])
test_data = test_data.sample(frac = 1, ignore_index = True, random_state = SEED)


print('total train images \t{0}'.format(train_data.shape[0]))
print('total valid images \t{0}'.format(valid_data.shape[0]))
print('total test images \t{0}'.format(test_data.shape[0]))
# Out:
# total train images 	9503
# total valid images 	2376
# total test images 	2000

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Print 25 random samples from the training data with inferno colormap
plt.figure(figsize=(15, 15))

for i in range(25):
    ax = plt.subplot(5, 5, i+1)
    random_index = np.random.randint(0, train_data.shape[0])
    img_path = train_data.loc[random_index, 'image']
    img = Image.open(img_path)
    plt.imshow(img)
    ax.set_title(f"Label: {classes[train_data.loc[random_index, 'label']]}")
    ax.axis('off')

plt.show()

# %%
# Reading -> Resizing -> Normalization
def img_preprocessing(image, label):
    img = tf.io.read_file(image)
    img = tf.io.decode_png(img, channels = 3)
    img = tf.image.resize(img, size =(IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0


    return img, label


# Data augmentation
img_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation((-0.3, 0.3), interpolation="bilinear"),
    RandomContrast(0.03),
    RandomCrop(*IMG_SIZE)])

# %%
# Creating dataset loaders and tf.datasets

train_loader = tf.data.Dataset.from_tensor_slices((train_data['image'], train_data['label']))
train_dataset = (train_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .shuffle(BATCH_SIZE*10)
                 .batch(BATCH_SIZE)
                 .map(lambda img, label: (img_augmentation(img), label), num_parallel_calls =AUTO)
                 .prefetch(AUTO))


valid_loader = tf.data.Dataset.from_tensor_slices((valid_data['image'], valid_data['label']))
valid_dataset = (valid_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

test_loader = tf.data.Dataset.from_tensor_slices((test_data['image'], test_data['label']))
test_dataset = (test_loader
                 .map(img_preprocessing, num_parallel_calls = AUTO)
                 .batch(BATCH_SIZE)
                 .prefetch(AUTO))

# %%
# Display original and augmented image for the first sample
def display_sample_images(dataset):
    for images, labels in dataset.take(1):
        # Display original image
        original_image = images[0].numpy()
        
        # Apply augmentation
        augmented_image = img_augmentation(images[0:1], training=True)[0].numpy()
        
        # Plotting
        plt.figure(figsize=(8, 4))
        
        # Original image
        plt.subplot(1, 2, 1)
        plt.title("Original Image")
        plt.imshow(original_image,cmap='inferno')
        plt.axis("off")
        
        # Augmented image
        plt.subplot(1, 2, 2)
        plt.title("Augmented Image")
        plt.imshow(augmented_image,cmap='inferno')
        plt.axis("off")
        
        plt.show()
        break

# Display original and augmented images from train dataset
display_sample_images(train_dataset)

# %%
# a custom callback for evaluation of test set during training each 10 loop
class Test_Pred_During_Training(Callback):

    def __init__(self, model):
        self._model = model

    def on_epoch_end(self, epochs, logs = None ):
        try:
            if (epochs+1) % 10 == 0:
                test_pred = self.model.predict(test_dataset, verbose = 0)
                test_pred = np.argmax(test_pred, axis = 1)

                mse = mean_squared_error(test_data['label'], test_pred)
                f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
                acc = accuracy_score(test_data['label'], test_pred)

                print('\nMean Squared Error : {0:.5f}'.format(mse))
                print('Weighted F1 Score : {0:.3f}'.format(f1))
                print('Accuracy Score : {0:.3f} %'.format(acc*100))

                print("--"*40)
        except ValueError:
            pass

# %%
pip install -q vit-keras
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow_addons) (21.3)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow_addons) (3.1.1)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 8.3 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.1.5
#     Uninstalling typeguard-4.1.5:
#       Successfully uninstalled typeguard-4.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires typeguard<5,>=4.1.2, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from vit_keras import vit
import tensorflow_addons as tfa
vit_model = vit.vit_b16(
        image_size = IMG_SIZE,
        activation = 'softmax',
        pretrained = True,
        include_top = False,
        pretrained_top = False,
        classes = 2)
# Out:
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-B_16_imagenet21k+imagenet2012.npz
# 347502902/347502902 [==============================] - 4s 0us/step

# %%
model = tf.keras.Sequential([
        vit_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(128, activation = tfa.activations.gelu),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(64, activation = tfa.activations.gelu),
        tf.keras.layers.Dense(32, activation = tfa.activations.gelu),
        tf.keras.layers.Dense(2, 'softmax')
    ],
    name = 'vision_transformer')

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
                    loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                    metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "vision_transformer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit-b16 (Functional)        (None, 768)               85798656
#
#  flatten (Flatten)           (None, 768)               0
#
#  batch_normalization (Batch  (None, 768)               3072
#  Normalization)
#
#  dense (Dense)               (None, 128)               98432
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 85911074 (327.72 MB)
# Trainable params: 85909282 (327.72 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %%
my_callbacks = [Test_Pred_During_Training(model=model),
                tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss',factor=0.1, min_delta = 0.01, patience=6),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0.01,patience=20),
                tf.keras.callbacks.ModelCheckpoint("/kaggle/working/my_model.tf", monitor="val_loss", mode="min", save_best_only=True, verbose=1)]

# %%
import time
start = time.time()
history = model.fit(
    train_dataset,
    batch_size=32,
    epochs=50,
    validation_data=valid_dataset,
    callbacks=[my_callbacks]
)
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717692379.540631      80 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 297/297 [==============================] - ETA: 0s - loss: 0.4680 - accuracy: 0.7722
# Epoch 1: val_loss improved from inf to 0.46693, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 327s 936ms/step - loss: 0.4680 - accuracy: 0.7722 - val_loss: 0.4669 - val_accuracy: 0.8106 - lr: 0.0010
# Epoch 2/50
# 297/297 [==============================] - ETA: 0s - loss: 0.4031 - accuracy: 0.8143
# Epoch 2: val_loss improved from 0.46693 to 0.42511, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 274s 922ms/step - loss: 0.4031 - accuracy: 0.8143 - val_loss: 0.4251 - val_accuracy: 0.7807 - lr: 0.0010
# Epoch 3/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.8225
# Epoch 3: val_loss improved from 0.42511 to 0.36974, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 276s 929ms/step - loss: 0.3912 - accuracy: 0.8225 - val_loss: 0.3697 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 4/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8188
# Epoch 4: val_loss did not improve from 0.36974
# 297/297 [==============================] - 239s 803ms/step - loss: 0.3856 - accuracy: 0.8188 - val_loss: 0.4595 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 5/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.8258
# Epoch 5: val_loss did not improve from 0.36974
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3771 - accuracy: 0.8258 - val_loss: 0.5796 - val_accuracy: 0.7348 - lr: 0.0010
# Epoch 6/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3789 - accuracy: 0.8269
# Epoch 6: val_loss did not improve from 0.36974
# 297/297 [==============================] - 239s 803ms/step - loss: 0.3789 - accuracy: 0.8269 - val_loss: 1.4414 - val_accuracy: 0.6111 - lr: 0.0010
# Epoch 7/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8321
# Epoch 7: val_loss improved from 0.36974 to 0.32935, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 275s 923ms/step - loss: 0.3678 - accuracy: 0.8321 - val_loss: 0.3293 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 8/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8381
# Epoch 8: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3603 - accuracy: 0.8381 - val_loss: 0.4800 - val_accuracy: 0.7769 - lr: 0.0010
# Epoch 9/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8350
# Epoch 9: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3628 - accuracy: 0.8350 - val_loss: 0.4227 - val_accuracy: 0.8089 - lr: 0.0010
# Epoch 10/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8359
# Mean Squared Error : 0.14350
# Weighted F1 Score : 0.856
# Accuracy Score : 85.650 %
# --------------------------------------------------------------------------------
#
# Epoch 10: val_loss did not improve from 0.32935
# 297/297 [==============================] - 258s 869ms/step - loss: 0.3563 - accuracy: 0.8359 - val_loss: 0.3849 - val_accuracy: 0.8245 - lr: 0.0010
# Epoch 11/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8420
# Epoch 11: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3470 - accuracy: 0.8420 - val_loss: 0.3632 - val_accuracy: 0.8308 - lr: 0.0010
# Epoch 12/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8406
# Epoch 12: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3520 - accuracy: 0.8406 - val_loss: 1.6063 - val_accuracy: 0.4853 - lr: 0.0010
# Epoch 13/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3500 - accuracy: 0.8422
# Epoch 13: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3500 - accuracy: 0.8422 - val_loss: 0.7032 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 14/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8559
# Epoch 14: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 805ms/step - loss: 0.3253 - accuracy: 0.8559 - val_loss: 0.3413 - val_accuracy: 0.8544 - lr: 1.0000e-04
# Epoch 15/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8596
# Epoch 15: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 805ms/step - loss: 0.3157 - accuracy: 0.8596 - val_loss: 0.3380 - val_accuracy: 0.8502 - lr: 1.0000e-04
# Epoch 16/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3090 - accuracy: 0.8610
# Epoch 16: val_loss did not improve from 0.32935
# 297/297 [==============================] - 239s 804ms/step - loss: 0.3090 - accuracy: 0.8610 - val_loss: 0.3386 - val_accuracy: 0.8514 - lr: 1.0000e-04
# Epoch 17/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.8667
# Epoch 17: val_loss improved from 0.32935 to 0.31928, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 276s 930ms/step - loss: 0.3053 - accuracy: 0.8667 - val_loss: 0.3193 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 18/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8676
# Epoch 18: val_loss improved from 0.31928 to 0.29970, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 272s 916ms/step - loss: 0.3052 - accuracy: 0.8676 - val_loss: 0.2997 - val_accuracy: 0.8653 - lr: 1.0000e-04
# Epoch 19/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8676
# Epoch 19: val_loss did not improve from 0.29970
# 297/297 [==============================] - 238s 801ms/step - loss: 0.3003 - accuracy: 0.8676 - val_loss: 0.3225 - val_accuracy: 0.8535 - lr: 1.0000e-04
# Epoch 20/50
# 297/297 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.8692
# Mean Squared Error : 0.13400
# Weighted F1 Score : 0.866
# Accuracy Score : 86.600 %
# --------------------------------------------------------------------------------
#
# Epoch 20: val_loss did not improve from 0.29970
# 297/297 [==============================] - 253s 852ms/step - loss: 0.3012 - accuracy: 0.8692 - val_loss: 0.3017 - val_accuracy: 0.8573 - lr: 1.0000e-04
# Epoch 21/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8684
# Epoch 21: val_loss did not improve from 0.29970
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2967 - accuracy: 0.8684 - val_loss: 0.3005 - val_accuracy: 0.8653 - lr: 1.0000e-04
# Epoch 22/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8737
# Epoch 22: val_loss did not improve from 0.29970
# 297/297 [==============================] - 238s 801ms/step - loss: 0.2955 - accuracy: 0.8737 - val_loss: 0.3000 - val_accuracy: 0.8653 - lr: 1.0000e-04
# Epoch 23/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8676
# Epoch 23: val_loss improved from 0.29970 to 0.29295, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 273s 918ms/step - loss: 0.2989 - accuracy: 0.8676 - val_loss: 0.2930 - val_accuracy: 0.8645 - lr: 1.0000e-04
# Epoch 24/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.8699
# Epoch 24: val_loss improved from 0.29295 to 0.29242, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 272s 915ms/step - loss: 0.2949 - accuracy: 0.8699 - val_loss: 0.2924 - val_accuracy: 0.8678 - lr: 1.0000e-04
# Epoch 25/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.8796
# Epoch 25: val_loss improved from 0.29242 to 0.28350, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 273s 919ms/step - loss: 0.2853 - accuracy: 0.8796 - val_loss: 0.2835 - val_accuracy: 0.8721 - lr: 1.0000e-05
# Epoch 26/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8759
# Epoch 26: val_loss did not improve from 0.28350
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2832 - accuracy: 0.8759 - val_loss: 0.2841 - val_accuracy: 0.8708 - lr: 1.0000e-05
# Epoch 27/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8719
# Epoch 27: val_loss improved from 0.28350 to 0.28350, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 272s 915ms/step - loss: 0.2840 - accuracy: 0.8719 - val_loss: 0.2835 - val_accuracy: 0.8729 - lr: 1.0000e-05
# Epoch 28/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.8756
# Epoch 28: val_loss improved from 0.28350 to 0.28274, saving model to /kaggle/working/my_model.tf
# 297/297 [==============================] - 272s 916ms/step - loss: 0.2849 - accuracy: 0.8756 - val_loss: 0.2827 - val_accuracy: 0.8716 - lr: 1.0000e-05
# Epoch 29/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.8758
# Epoch 29: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2845 - accuracy: 0.8758 - val_loss: 0.2830 - val_accuracy: 0.8742 - lr: 1.0000e-05
# Epoch 30/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.8801
# Mean Squared Error : 0.11850
# Weighted F1 Score : 0.881
# Accuracy Score : 88.150 %
# --------------------------------------------------------------------------------
#
# Epoch 30: val_loss did not improve from 0.28274
# 297/297 [==============================] - 254s 853ms/step - loss: 0.2830 - accuracy: 0.8801 - val_loss: 0.2840 - val_accuracy: 0.8742 - lr: 1.0000e-05
# Epoch 31/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8747
# Epoch 31: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2847 - accuracy: 0.8747 - val_loss: 0.2830 - val_accuracy: 0.8716 - lr: 1.0000e-05
# Epoch 32/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8745
# Epoch 32: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2792 - accuracy: 0.8745 - val_loss: 0.2830 - val_accuracy: 0.8729 - lr: 1.0000e-06
# Epoch 33/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2813 - accuracy: 0.8810
# Epoch 33: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2813 - accuracy: 0.8810 - val_loss: 0.2832 - val_accuracy: 0.8733 - lr: 1.0000e-06
# Epoch 34/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8774
# Epoch 34: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2805 - accuracy: 0.8774 - val_loss: 0.2831 - val_accuracy: 0.8742 - lr: 1.0000e-06
# Epoch 35/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8764
# Epoch 35: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2819 - accuracy: 0.8764 - val_loss: 0.2830 - val_accuracy: 0.8746 - lr: 1.0000e-06
# Epoch 36/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.8767
# Epoch 36: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 799ms/step - loss: 0.2815 - accuracy: 0.8767 - val_loss: 0.2829 - val_accuracy: 0.8742 - lr: 1.0000e-06
# Epoch 37/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8754
# Epoch 37: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2803 - accuracy: 0.8754 - val_loss: 0.2828 - val_accuracy: 0.8742 - lr: 1.0000e-06
# Epoch 38/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8767
# Epoch 38: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2885 - accuracy: 0.8767 - val_loss: 0.2829 - val_accuracy: 0.8742 - lr: 1.0000e-07
# Epoch 39/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.8796
# Epoch 39: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 801ms/step - loss: 0.2816 - accuracy: 0.8796 - val_loss: 0.2830 - val_accuracy: 0.8750 - lr: 1.0000e-07
# Epoch 40/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2818 - accuracy: 0.8782
# Mean Squared Error : 0.11900
# Weighted F1 Score : 0.881
# Accuracy Score : 88.100 %
# --------------------------------------------------------------------------------
#
# Epoch 40: val_loss did not improve from 0.28274
# 297/297 [==============================] - 254s 853ms/step - loss: 0.2818 - accuracy: 0.8782 - val_loss: 0.2830 - val_accuracy: 0.8746 - lr: 1.0000e-07
# Epoch 41/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8784
# Epoch 41: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 801ms/step - loss: 0.2822 - accuracy: 0.8784 - val_loss: 0.2829 - val_accuracy: 0.8746 - lr: 1.0000e-07
# Epoch 42/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.8772
# Epoch 42: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 801ms/step - loss: 0.2827 - accuracy: 0.8772 - val_loss: 0.2829 - val_accuracy: 0.8746 - lr: 1.0000e-07
# Epoch 43/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8784
# Epoch 43: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2809 - accuracy: 0.8784 - val_loss: 0.2831 - val_accuracy: 0.8746 - lr: 1.0000e-07
# Epoch 44/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8788
# Epoch 44: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2771 - accuracy: 0.8788 - val_loss: 0.2831 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 45/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.8776
# Epoch 45: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2816 - accuracy: 0.8776 - val_loss: 0.2829 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 46/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.8790
# Epoch 46: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2825 - accuracy: 0.8790 - val_loss: 0.2831 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 47/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8754
# Epoch 47: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2866 - accuracy: 0.8754 - val_loss: 0.2832 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 48/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8804
# Epoch 48: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2810 - accuracy: 0.8804 - val_loss: 0.2830 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 49/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.8784
# Epoch 49: val_loss did not improve from 0.28274
# 297/297 [==============================] - 238s 800ms/step - loss: 0.2841 - accuracy: 0.8784 - val_loss: 0.2831 - val_accuracy: 0.8746 - lr: 1.0000e-08
# Epoch 50/50
# 297/297 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.8781
# Mean Squared Error : 0.11850
# Weighted F1 Score : 0.881
# Accuracy Score : 88.150 %
# --------------------------------------------------------------------------------
#
# Epoch 50: val_loss did not improve from 0.28274
# 297/297 [==============================] - 253s 852ms/step - loss: 0.2783 - accuracy: 0.8781 - val_loss: 0.2830 - val_accuracy: 0.8750 - lr: 1.0000e-09
# Total time:  12686.817124128342 seconds

# %%
# Print training results
print("Training Results:")
print("Loss:", history.history['loss'][-1])
print("Accuracy:", history.history['accuracy'][-1])
print("Validation Loss:", history.history['val_loss'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Training Results:
# Loss: 0.27826637029647827
# Accuracy: 0.8781437277793884
# Validation Loss: 0.2830110490322113
# Validation Accuracy: 0.875

# %%
fig, axs = plt.subplots(1, 1, figsize=(5, 5), dpi=100)

axs.grid(linestyle='dashdot')
axs.plot(history.history['loss'])
axs.plot(history.history['val_loss'])
axs.set_xlabel('epochs', fontsize=10)
axs.set_ylabel('Loss', fontsize=10)
axs.legend(['Train Loss', 'Validation Loss'], fontsize=10)
axs.set_ylim(0, 1)
print(f'Giá trị loss cuối cùng: Train Loss = {history.history["loss"][-1]:.4f}, Validation Loss = {history.history["val_loss"][-1]:.4f}')
# Out:
# Giá trị loss cuối cùng: Train Loss = 0.2783, Validation Loss = 0.2830

# %%
fig, axs = plt.subplots(1,1, figsize = (5, 5), dpi = 100)
axs.grid(linestyle = 'dashdot')
axs.plot(history.history['accuracy'])
axs.plot(history.history['val_accuracy'])
axs.set_xlabel('epochs', fontsize = 10)
axs.legend(['train accuracy', 'validation accuracy'], fontsize = 10)
axs.set_ylim(0, 1)
print(f'Giá trị acc cuối cùng: Train Accuracy = {history.history["accuracy"][-1]:.4f}, Validation Accuracy = {history.history["val_accuracy"][-1]:.4f}')
# Out:
# Giá trị acc cuối cùng: Train Accuracy = 0.8781, Validation Accuracy = 0.8750

# %%
# Predictions and scores
test_pred = model.predict(test_dataset)
test_pred = np.argmax(test_pred, axis = 1)

mse = mean_squared_error(test_data['label'], test_pred)
f1 = f1_score(test_data['label'], test_pred, average = 'weighted')
acc = accuracy_score(test_data['label'], test_pred)

print('Mean Squared Error : {0:.5f}'.format(mse))
print('Weighted F1 Score : {0:.3f}'.format(f1))
print('Accuracy Score : {0:.3f} %'.format(acc*100))
# Out:
# 63/63 [==============================] - 16s 245ms/step
# Mean Squared Error : 0.11850
# Weighted F1 Score : 0.881
# Accuracy Score : 88.150 %

# %%
clf = classification_report(test_data['label'], test_pred, target_names = list(classes.values()))
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.86      0.91      0.88      1000
#    Malignant       0.90      0.85      0.88      1000
#
#     accuracy                           0.88      2000
#    macro avg       0.88      0.88      0.88      2000
# weighted avg       0.88      0.88      0.88      2000

# %%
cm = confusion_matrix(test_data['label'], test_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels = list(classes.values()))

fig, ax = plt.subplots(figsize=(5,5))
cmd.plot(ax=ax,  cmap = 'Blues', colorbar = False)

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_dataset)

# Print test results
print("\nTest Results:")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 63/63 [==============================] - 16s 249ms/step - loss: 0.2940 - accuracy: 0.8815
#
# Test Results:
# Test Loss: 0.29398390650749207
# Test Accuracy: 0.8815000057220459

# %%
import matplotlib.pyplot as plt

# Create a bar chart
x = ['Test Loss', 'Test Accuracy']
y = [test_loss, test_acc]

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(x, y)

# Add labels and title
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Model Evaluation on Test Set')

# Add value labels to the bars
for i, v in enumerate(y):
    ax.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=10)

plt.show()

# %%
test_take1 =  test_dataset.take(-1)
test_take1_ = list(test_take1)

# A function that creating 5 random images in the test set and predictions

# Red title -> a false prediction
# Green title -> a true prediction

def random_test_sample_with_prediction(SEED):
    
    idxs = np.random.default_rng(seed=SEED).permutation(len(test_pred))[:5]
    batch_idx = idxs // BATCH_SIZE
    image_idx = idxs - batch_idx * BATCH_SIZE
    idx = idxs

    fig, axs = plt.subplots(1, 5, figsize=(12, 12), dpi=150)

    for i in range(5):
        img = test_take1_[batch_idx[i]][0][image_idx[i]]
        label = test_take1_[batch_idx[i]][1][image_idx[i]].numpy()
        pred_label = int(test_pred[idx[i]])
        pred_prob = model.predict(tf.expand_dims(img, axis=0))[0][pred_label]

        if pred_label == label:
            axs[i].imshow(img, cmap='gray') 
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='green')
        else:
            axs[i].imshow(img, cmap='gray')
            axs[i].axis('off')
            axs[i].set_title('image (no: ' + str(idx[i]) + ')' + '\nTRUE: ' + classes[label] + '\nPRED: ' + classes[pred_label] + f' ({pred_prob:.2%})', fontsize=8, color='red')

# %%
# Red title -> a false prediction
# Green title -> a true prediction

random_test_sample_with_prediction(21)
random_test_sample_with_prediction(204)
random_test_sample_with_prediction(293)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step

# %%
loaded_model = tf.keras.models.load_model('/kaggle/working/my_model.tf', safe_mode=False)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# 5742
test_image_path = '/kaggle/input/melanoma-cancer-dataset/test/Malignant/5742.jpg'

test_image = cv2.imread(test_image_path)
test_image = cv2.resize(test_image, (224, 224))
test_image_display = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
test_image_normalized = test_image / 255.0
test_image_normalized = np.expand_dims(test_image_normalized, axis=0)

predictions = loaded_model.predict(test_image_normalized)
predicted_class_index = np.argmax(predictions)
if predicted_class_index == 0:
    predicted_class = 'Benign'
else:
    predicted_class = 'Malignant'

predicted_accuracy = np.max(predictions) *100

# if predicted_class_index == 1:
#     bounding_box = [50, 70, 150, 120]
#     cv2.rectangle(test_image_display, (bounding_box[0], bounding_box[1]), (bounding_box[2], bounding_box[3]), (0, 255, 0), 2)

plt.imshow(test_image_display)
plt.title(f"{predicted_class} ({predicted_accuracy:.2f}% accuracy)")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
